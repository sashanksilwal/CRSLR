# %% [markdown]
# Python tifffile package: https://github.com/cgohlke/tifffile/

# %%
import numpy as np
import matplotlib.pyplot as plt
import tifffile as tf
import geopandas as gpd
from osgeo import gdal

# %% [markdown]
# ### Using tifffile

# %%
lu = plt.imread('ConwyLU.tif')
slope = plt.imread('ConwySlope.tif')
status = plt.imread('ConwyStatus.tif')
print(lu.shape, slope.shape, status.shape)
# Out:
# (207, 150) (234, 159, 4) (188, 136, 4)

# %%
fig, axs = plt.subplots(1, 3, figsize=(20, 6))
axs[0].imshow(lu, cmap='gray')
axs[1].imshow(slope)
axs[2].imshow(status)

plt.show()

# %% [markdown]
# ### Using GDAL

# %%
lu2 = gdal.Open(r'ConwyLU.tif')
slope2 = gdal.Open(r'ConwySlope.tif')
status2 = gdal.Open(r'ConwyStatus.tif')
files = [lu2, slope2, status2]

# %%
print('ConwyLU: # of bands: {}, X: {}, Y: {}'.format(lu2.RasterCount, lu2.RasterXSize, lu2.RasterYSize))
print('ConwySlope: # of bands: {}, X: {}, Y: {}'.format(slope2.RasterCount, slope2.RasterXSize, slope2.RasterYSize))
print('ConwyStatus: # of bands: {}, X: {}, Y: {}'.format(status2.RasterCount, status2.RasterXSize, status2.RasterYSize))
# Out:
# ConwyLU: # of bands: 1, X: 150, Y: 207
# ConwySlope: # of bands: 1, X: 159, Y: 234
# ConwyStatus: # of bands: 1, X: 136, Y: 188

# %%
bands = [lu2.GetRasterBand(1), slope2.GetRasterBand(1), status2.GetRasterBand(1)]

print("Statistics: min, max, mean, standard deviation")
print('ConwyLU: {}'.format(bands[0].GetStatistics(True, True)))
print('ConwySlope: {}'.format(bands[1].GetStatistics(True, True)))
print('ConwyStatus: {}'.format(bands[2].GetStatistics(True, True)))

arrs = [band.ReadAsArray() for band in bands]

fig, axs = plt.subplots(1, 3, figsize=(24, 8))
axs[0].imshow(arrs[0], cmap='GnBu')
axs[0].set_title('Conwy LU')
axs[1].imshow(arrs[1], cmap='GnBu')
axs[1].set_title('Conwy Slope')
axs[2].imshow(arrs[2], cmap='GnBu')
axs[2].set_title('Conwy Status')

plt.show()
# Out:
# Statistics: min, max, mean, standard deviation
# ConwyLU: [1.0, 3.0, 2.1909979969365, 0.89966755095785]
# ConwySlope: [0.0, 43.0, 8.8781044435495, 6.5999558465119]
# ConwyStatus: [1.0, 4.0, 3.4168818448936, 0.87562008061435]

# %% [markdown]
# ### Using rasterio
# https://rasterio.readthedocs.io/en/latest/

# %%
import rasterio
import rasterio.features
import rasterio.warp

# %%
dataset = rasterio.open('ConwyLU.tif')
mask = dataset.dataset_mask()

# %%
for geom, val in rasterio.features.shapes(
            mask, transform=dataset.transform):
    print(geom)
# Out:
# {'type': 'Polygon', 'coordinates': [[(277850.00000000093, 370000.0), (277850.00000000093, 369800.0), (278050.00000000093, 369800.0), (278050.00000000093, 370000.0), (277850.00000000093, 370000.0)]]}
# {'type': 'Polygon', 'coordinates': [[(263850.00000000093, 382000.0), (263850.00000000093, 358000.0), (264250.00000000093, 358000.0), (264250.00000000093, 358200.0), (264850.00000000093, 358200.0), (264850.00000000093, 358400.0), (265650.00000000093, 358400.0), (265650.00000000093, 358600.0), (266050.00000000093, 358600.0), (266050.00000000093, 358400.0), (267050.00000000093, 358400.0), (267050.00000000093, 358600.0), (267250.00000000093, 358600.0), (267250.00000000093, 359000.0), (267450.00000000093, 359000.0), (267450.00000000093, 359600.0), (267250.00000000093, 359600.0), (267250.00000000093, 360000.0), (267450.00000000093, 360000.0), (267450.00000000093, 360600.0), (267650.00000000093, 360600.0), (267650.00000000093, 360800.0), (267850.00000000093, 360800.0), (267850.00000000093, 361200.0), (268050.00000000093, 361200.0), (268050.00000000093, 361400.0), (268250.00000000093, 361400.0), (268250.00000000093, 361600.0), (268050.00000000093, 361600.0), (268050.00000000093, 362000.0), (268250.00000000093, 362000.0), (268250.00000000093, 362800.0), (267850.00000000093, 362800.0), (267850.00000000093, 363000.0), (267650.00000000093, 363000.0), (267650.00000000093, 363400.0), (267850.00000000093, 363400.0), (267850.00000000093, 363800.0), (268050.00000000093, 363800.0), (268050.00000000093, 364000.0), (268250.00000000093, 364000.0), (268250.00000000093, 364800.0), (268450.00000000093, 364800.0), (268450.00000000093, 365000.0), (268650.00000000093, 365000.0), (268650.00000000093, 365400.0), (268850.00000000093, 365400.0), (268850.00000000093, 366400.0), (268650.00000000093, 366400.0), (268650.00000000093, 367200.0), (268850.00000000093, 367200.0), (268850.00000000093, 367400.0), (269050.00000000093, 367400.0), (269050.00000000093, 367600.0), (269250.00000000093, 367600.0), (269250.00000000093, 367800.0), (269450.00000000093, 367800.0), (269450.00000000093, 368200.0), (269650.00000000093, 368200.0), (269650.00000000093, 368400.0), (270050.00000000093, 368400.0), (270050.00000000093, 368600.0), (270250.00000000093, 368600.0), (270250.00000000093, 368800.0), (270450.00000000093, 368800.0), (270450.00000000093, 369000.0), (270650.00000000093, 369000.0), (270650.00000000093, 370000.0), (270850.00000000093, 370000.0), (270850.00000000093, 370400.0), (270650.00000000093, 370400.0), (270650.00000000093, 370600.0), (270450.00000000093, 370600.0), (270450.00000000093, 371200.0), (270650.00000000093, 371200.0), (270650.00000000093, 371600.0), (271050.00000000093, 371600.0), (271050.00000000093, 371800.0), (271250.00000000093, 371800.0), (271250.00000000093, 372000.0), (271450.00000000093, 372000.0), (271450.00000000093, 372200.0), (271850.00000000093, 372200.0), (271850.00000000093, 372400.0), (272650.00000000093, 372400.0), (272650.00000000093, 372600.0), (272850.00000000093, 372600.0), (272850.00000000093, 372800.0), (273250.00000000093, 372800.0), (273250.00000000093, 373000.0), (273450.00000000093, 373000.0), (273450.00000000093, 373200.0), (273650.00000000093, 373200.0), (273650.00000000093, 373800.0), (273850.00000000093, 373800.0), (273850.00000000093, 374200.0), (274050.00000000093, 374200.0), (274050.00000000093, 374800.0), (274250.00000000093, 374800.0), (274250.00000000093, 375200.0), (274450.00000000093, 375200.0), (274450.00000000093, 375600.0), (274650.00000000093, 375600.0), (274650.00000000093, 375800.0), (274850.00000000093, 375800.0), (274850.00000000093, 376200.0), (275250.00000000093, 376200.0), (275250.00000000093, 376400.0), (275650.00000000093, 376400.0), (275650.00000000093, 376600.0), (276050.00000000093, 376600.0), (276050.00000000093, 376400.0), (276250.00000000093, 376400.0), (276250.00000000093, 376600.0), (276450.00000000093, 376600.0), (276450.00000000093, 377400.0), (277250.00000000093, 377400.0), (277250.00000000093, 377600.0), (277850.00000000093, 377600.0), (277850.00000000093, 377800.0), (278050.00000000093, 377800.0), (278050.00000000093, 377600.0), (278450.00000000093, 377600.0), (278450.00000000093, 377400 ...
# {'type': 'Polygon', 'coordinates': [[(281650.00000000093, 382000.0), (281650.00000000093, 381800.0), (281850.00000000093, 381800.0), (281850.00000000093, 381400.0), (282050.00000000093, 381400.0), (282050.00000000093, 381200.0), (282250.00000000093, 381200.0), (282250.00000000093, 381000.0), (282850.00000000093, 381000.0), (282850.00000000093, 381200.0), (283450.00000000093, 381200.0), (283450.00000000093, 380200.0), (283250.00000000093, 380200.0), (283250.00000000093, 379800.0), (283650.00000000093, 379800.0), (283650.00000000093, 378800.0), (283850.00000000093, 378800.0), (283850.00000000093, 378000.0), (284050.00000000093, 378000.0), (284050.00000000093, 377800.0), (284250.00000000093, 377800.0), (284250.00000000093, 377200.0), (284050.00000000093, 377200.0), (284050.00000000093, 377000.0), (283850.00000000093, 377000.0), (283850.00000000093, 376800.0), (283650.00000000093, 376800.0), (283650.00000000093, 375800.0), (283450.00000000093, 375800.0), (283450.00000000093, 375600.0), (283250.00000000093, 375600.0), (283250.00000000093, 375200.0), (283650.00000000093, 375200.0), (283650.00000000093, 375000.0), (283850.00000000093, 375000.0), (283850.00000000093, 374800.0), (284050.00000000093, 374800.0), (284050.00000000093, 374600.0), (284250.00000000093, 374600.0), (284250.00000000093, 374400.0), (284450.00000000093, 374400.0), (284450.00000000093, 374000.0), (284050.00000000093, 374000.0), (284050.00000000093, 373400.0), (283850.00000000093, 373400.0), (283850.00000000093, 373200.0), (283650.00000000093, 373200.0), (283650.00000000093, 373000.0), (283850.00000000093, 373000.0), (283850.00000000093, 372600.0), (284050.00000000093, 372600.0), (284050.00000000093, 372400.0), (284250.00000000093, 372400.0), (284250.00000000093, 372000.0), (284050.00000000093, 372000.0), (284050.00000000093, 371800.0), (283650.00000000093, 371800.0), (283650.00000000093, 371600.0), (283850.00000000093, 371600.0), (283850.00000000093, 371400.0), (284050.00000000093, 371400.0), (284050.00000000093, 371200.0), (284250.00000000093, 371200.0), (284250.00000000093, 370600.0), (284050.00000000093, 370600.0), (284050.00000000093, 370400.0), (283650.00000000093, 370400.0), (283650.00000000093, 370000.0), (283250.00000000093, 370000.0), (283250.00000000093, 369600.0), (283050.00000000093, 369600.0), (283050.00000000093, 369200.0), (283250.00000000093, 369200.0), (283250.00000000093, 368800.0), (283050.00000000093, 368800.0), (283050.00000000093, 368000.0), (282850.00000000093, 368000.0), (282850.00000000093, 367600.0), (283050.00000000093, 367600.0), (283050.00000000093, 367000.0), (283250.00000000093, 367000.0), (283250.00000000093, 366600.0), (283050.00000000093, 366600.0), (283050.00000000093, 366000.0), (283250.00000000093, 366000.0), (283250.00000000093, 364800.0), (283050.00000000093, 364800.0), (283050.00000000093, 364600.0), (282850.00000000093, 364600.0), (282850.00000000093, 363600.0), (283050.00000000093, 363600.0), (283050.00000000093, 363400.0), (283250.00000000093, 363400.0), (283250.00000000093, 363200.0), (283650.00000000093, 363200.0), (283650.00000000093, 362800.0), (283850.00000000093, 362800.0), (283850.00000000093, 362600.0), (284250.00000000093, 362600.0), (284250.00000000093, 361600.0), (284450.00000000093, 361600.0), (284450.00000000093, 361400.0), (284650.00000000093, 361400.0), (284650.00000000093, 361000.0), (284850.00000000093, 361000.0), (284850.00000000093, 360000.0), (285050.00000000093, 360000.0), (285050.00000000093, 359800.0), (284850.00000000093, 359800.0), (284850.00000000093, 359400.0), (285050.00000000093, 359400.0), (285050.00000000093, 359200.0), (284850.00000000093, 359200.0), (284850.00000000093, 358800.0), (285050.00000000093, 358800.0), (285050.00000000093, 358400.0), (285250.00000000093, 358400.0), (285250.00000000093, 358200.0), (285450.00000000093, 358200.0), (285450.00000000093, 357800.0), (285650.00000000093, 357800.0), (285650.00000000093, 357600.0), (285850.00000000093, 357600.0), (285850.00000000093, 357400 ...
# {'type': 'Polygon', 'coordinates': [[(263850.00000000093, 356600.0), (263850.00000000093, 340600.0), (277650.00000000093, 340600.0), (277650.00000000093, 340800.0), (277250.00000000093, 340800.0), (277250.00000000093, 341200.0), (277050.00000000093, 341200.0), (277050.00000000093, 341400.0), (276850.00000000093, 341400.0), (276850.00000000093, 342000.0), (276250.00000000093, 342000.0), (276250.00000000093, 343000.0), (276050.00000000093, 343000.0), (276050.00000000093, 343400.0), (275850.00000000093, 343400.0), (275850.00000000093, 343600.0), (275650.00000000093, 343600.0), (275650.00000000093, 344000.0), (275850.00000000093, 344000.0), (275850.00000000093, 344400.0), (275650.00000000093, 344400.0), (275650.00000000093, 344600.0), (275050.00000000093, 344600.0), (275050.00000000093, 344800.0), (274850.00000000093, 344800.0), (274850.00000000093, 345000.0), (274650.00000000093, 345000.0), (274650.00000000093, 344800.0), (274250.00000000093, 344800.0), (274250.00000000093, 345000.0), (273650.00000000093, 345000.0), (273650.00000000093, 345400.0), (273450.00000000093, 345400.0), (273450.00000000093, 345600.0), (273250.00000000093, 345600.0), (273250.00000000093, 345800.0), (272650.00000000093, 345800.0), (272650.00000000093, 346200.0), (272850.00000000093, 346200.0), (272850.00000000093, 346600.0), (273050.00000000093, 346600.0), (273050.00000000093, 347000.0), (273250.00000000093, 347000.0), (273250.00000000093, 347600.0), (273050.00000000093, 347600.0), (273050.00000000093, 347800.0), (272850.00000000093, 347800.0), (272850.00000000093, 348000.0), (272650.00000000093, 348000.0), (272650.00000000093, 348200.0), (271650.00000000093, 348200.0), (271650.00000000093, 348400.0), (271450.00000000093, 348400.0), (271450.00000000093, 348800.0), (271050.00000000093, 348800.0), (271050.00000000093, 348600.0), (270450.00000000093, 348600.0), (270450.00000000093, 348400.0), (270250.00000000093, 348400.0), (270250.00000000093, 348600.0), (269250.00000000093, 348600.0), (269250.00000000093, 348400.0), (268850.00000000093, 348400.0), (268850.00000000093, 348200.0), (268650.00000000093, 348200.0), (268650.00000000093, 347800.0), (268250.00000000093, 347800.0), (268250.00000000093, 347400.0), (267650.00000000093, 347400.0), (267650.00000000093, 347600.0), (266850.00000000093, 347600.0), (266850.00000000093, 347800.0), (266650.00000000093, 347800.0), (266650.00000000093, 348000.0), (266250.00000000093, 348000.0), (266250.00000000093, 349400.0), (266450.00000000093, 349400.0), (266450.00000000093, 350000.0), (266250.00000000093, 350000.0), (266250.00000000093, 350200.0), (266050.00000000093, 350200.0), (266050.00000000093, 350600.0), (265850.00000000093, 350600.0), (265850.00000000093, 351000.0), (266050.00000000093, 351000.0), (266050.00000000093, 351200.0), (266250.00000000093, 351200.0), (266250.00000000093, 352000.0), (266450.00000000093, 352000.0), (266450.00000000093, 352600.0), (266650.00000000093, 352600.0), (266650.00000000093, 352800.0), (266850.00000000093, 352800.0), (266850.00000000093, 353000.0), (267050.00000000093, 353000.0), (267050.00000000093, 353200.0), (267250.00000000093, 353200.0), (267250.00000000093, 353600.0), (267450.00000000093, 353600.0), (267450.00000000093, 353800.0), (267250.00000000093, 353800.0), (267250.00000000093, 354000.0), (267050.00000000093, 354000.0), (267050.00000000093, 354200.0), (266650.00000000093, 354200.0), (266650.00000000093, 354600.0), (266450.00000000093, 354600.0), (266450.00000000093, 355000.0), (266250.00000000093, 355000.0), (266250.00000000093, 355400.0), (266050.00000000093, 355400.0), (266050.00000000093, 355600.0), (265850.00000000093, 355600.0), (265850.00000000093, 355800.0), (265250.00000000093, 355800.0), (265250.00000000093, 355600.0), (265050.00000000093, 355600.0), (265050.00000000093, 355800.0), (264650.00000000093, 355800.0), (264650.00000000093, 356000.0), (264450.00000000093, 356000.0), (264450.00000000093, 356200.0), (264250.00000000093, 356200.0), (264250.00000000093, 356400 ...
# {'type': 'Polygon', 'coordinates': [[(281250.00000000093, 382000.0), (281250.00000000093, 381800.0), (280850.00000000093, 381800.0), (280850.00000000093, 381400.0), (280250.00000000093, 381400.0), (280250.00000000093, 381200.0), (280050.00000000093, 381200.0), (280050.00000000093, 381000.0), (279850.00000000093, 381000.0), (279850.00000000093, 380600.0), (279050.00000000093, 380600.0), (279050.00000000093, 380400.0), (278850.00000000093, 380400.0), (278850.00000000093, 380600.0), (278450.00000000093, 380600.0), (278450.00000000093, 380000.0), (278250.00000000093, 380000.0), (278250.00000000093, 379600.0), (278450.00000000093, 379600.0), (278450.00000000093, 379200.0), (278850.00000000093, 379200.0), (278850.00000000093, 378800.0), (279050.00000000093, 378800.0), (279050.00000000093, 378000.0), (278850.00000000093, 378000.0), (278850.00000000093, 377800.0), (279250.00000000093, 377800.0), (279250.00000000093, 377600.0), (279450.00000000093, 377600.0), (279450.00000000093, 377400.0), (279850.00000000093, 377400.0), (279850.00000000093, 377200.0), (280250.00000000093, 377200.0), (280250.00000000093, 376600.0), (280050.00000000093, 376600.0), (280050.00000000093, 375800.0), (279850.00000000093, 375800.0), (279850.00000000093, 375600.0), (279650.00000000093, 375600.0), (279650.00000000093, 375400.0), (279250.00000000093, 375400.0), (279250.00000000093, 375200.0), (279050.00000000093, 375200.0), (279050.00000000093, 375000.0), (278850.00000000093, 375000.0), (278850.00000000093, 374800.0), (278650.00000000093, 374800.0), (278650.00000000093, 374400.0), (278450.00000000093, 374400.0), (278450.00000000093, 374200.0), (278650.00000000093, 374200.0), (278650.00000000093, 374000.0), (278850.00000000093, 374000.0), (278850.00000000093, 373600.0), (278650.00000000093, 373600.0), (278650.00000000093, 373800.0), (278450.00000000093, 373800.0), (278450.00000000093, 374000.0), (278250.00000000093, 374000.0), (278250.00000000093, 374800.0), (278450.00000000093, 374800.0), (278450.00000000093, 375200.0), (278850.00000000093, 375200.0), (278850.00000000093, 375400.0), (279050.00000000093, 375400.0), (279050.00000000093, 375600.0), (279450.00000000093, 375600.0), (279450.00000000093, 376000.0), (279250.00000000093, 376000.0), (279250.00000000093, 376600.0), (279050.00000000093, 376600.0), (279050.00000000093, 377200.0), (278650.00000000093, 377200.0), (278650.00000000093, 377400.0), (278450.00000000093, 377400.0), (278450.00000000093, 377600.0), (278050.00000000093, 377600.0), (278050.00000000093, 377800.0), (277850.00000000093, 377800.0), (277850.00000000093, 377600.0), (277250.00000000093, 377600.0), (277250.00000000093, 377400.0), (276450.00000000093, 377400.0), (276450.00000000093, 376600.0), (276250.00000000093, 376600.0), (276250.00000000093, 376400.0), (276050.00000000093, 376400.0), (276050.00000000093, 376600.0), (275650.00000000093, 376600.0), (275650.00000000093, 376400.0), (275250.00000000093, 376400.0), (275250.00000000093, 376200.0), (274850.00000000093, 376200.0), (274850.00000000093, 375800.0), (274650.00000000093, 375800.0), (274650.00000000093, 375600.0), (274450.00000000093, 375600.0), (274450.00000000093, 375200.0), (274250.00000000093, 375200.0), (274250.00000000093, 374800.0), (274050.00000000093, 374800.0), (274050.00000000093, 374200.0), (273850.00000000093, 374200.0), (273850.00000000093, 373800.0), (273650.00000000093, 373800.0), (273650.00000000093, 373200.0), (273450.00000000093, 373200.0), (273450.00000000093, 373000.0), (273250.00000000093, 373000.0), (273250.00000000093, 372800.0), (272850.00000000093, 372800.0), (272850.00000000093, 372600.0), (272650.00000000093, 372600.0), (272650.00000000093, 372400.0), (271850.00000000093, 372400.0), (271850.00000000093, 372200.0), (271450.00000000093, 372200.0), (271450.00000000093, 372000.0), (271250.00000000093, 372000.0), (271250.00000000093, 371800.0), (271050.00000000093, 371800.0), (271050.00000000093, 371600.0), (270650.00000000093, 371600.0), (270650.00000000093, 371200 ...
# {'type': 'Polygon', 'coordinates': [[(293650.00000000093, 351800.0), (293650.00000000093, 351200.0), (293450.00000000093, 351200.0), (293450.00000000093, 351000.0), (293250.00000000093, 351000.0), (293250.00000000093, 350800.0), (293050.00000000093, 350800.0), (293050.00000000093, 350200.0), (292850.00000000093, 350200.0), (292850.00000000093, 349600.0), (293050.00000000093, 349600.0), (293050.00000000093, 348000.0), (292050.00000000093, 348000.0), (292050.00000000093, 348200.0), (290850.00000000093, 348200.0), (290850.00000000093, 348000.0), (290250.00000000093, 348000.0), (290250.00000000093, 348200.0), (289450.00000000093, 348200.0), (289450.00000000093, 348000.0), (289050.00000000093, 348000.0), (289050.00000000093, 348200.0), (288050.00000000093, 348200.0), (288050.00000000093, 348000.0), (287850.00000000093, 348000.0), (287850.00000000093, 347600.0), (287650.00000000093, 347600.0), (287650.00000000093, 347200.0), (287450.00000000093, 347200.0), (287450.00000000093, 347000.0), (287250.00000000093, 347000.0), (287250.00000000093, 346600.0), (287450.00000000093, 346600.0), (287450.00000000093, 346400.0), (287650.00000000093, 346400.0), (287650.00000000093, 346200.0), (287850.00000000093, 346200.0), (287850.00000000093, 345600.0), (287650.00000000093, 345600.0), (287650.00000000093, 345400.0), (287450.00000000093, 345400.0), (287450.00000000093, 345000.0), (287250.00000000093, 345000.0), (287250.00000000093, 344800.0), (286850.00000000093, 344800.0), (286850.00000000093, 345000.0), (286050.00000000093, 345000.0), (286050.00000000093, 344600.0), (285650.00000000093, 344600.0), (285650.00000000093, 344800.0), (285250.00000000093, 344800.0), (285250.00000000093, 345000.0), (284650.00000000093, 345000.0), (284650.00000000093, 345200.0), (284250.00000000093, 345200.0), (284250.00000000093, 345600.0), (284050.00000000093, 345600.0), (284050.00000000093, 345800.0), (283850.00000000093, 345800.0), (283850.00000000093, 346200.0), (283650.00000000093, 346200.0), (283650.00000000093, 346000.0), (283050.00000000093, 346000.0), (283050.00000000093, 345200.0), (282850.00000000093, 345200.0), (282850.00000000093, 344200.0), (282650.00000000093, 344200.0), (282650.00000000093, 344000.0), (282250.00000000093, 344000.0), (282250.00000000093, 343600.0), (282050.00000000093, 343600.0), (282050.00000000093, 343400.0), (281450.00000000093, 343400.0), (281450.00000000093, 343000.0), (281650.00000000093, 343000.0), (281650.00000000093, 342800.0), (281450.00000000093, 342800.0), (281450.00000000093, 342400.0), (281650.00000000093, 342400.0), (281650.00000000093, 341800.0), (281850.00000000093, 341800.0), (281850.00000000093, 341600.0), (280250.00000000093, 341600.0), (280250.00000000093, 341400.0), (280050.00000000093, 341400.0), (280050.00000000093, 341200.0), (279850.00000000093, 341200.0), (279850.00000000093, 341400.0), (279250.00000000093, 341400.0), (279250.00000000093, 341200.0), (279050.00000000093, 341200.0), (279050.00000000093, 341000.0), (278650.00000000093, 341000.0), (278650.00000000093, 340800.0), (278450.00000000093, 340800.0), (278450.00000000093, 340600.0), (293850.00000000093, 340600.0), (293850.00000000093, 351800.0), (293650.00000000093, 351800.0)]]}

# %% [markdown]
# ### Using geopandas

# %%
shp = gpd.read_file('Conwy.shp')
shp
# Out:
#        LU  Status  Slope                                           geometry
# 0     1.0     4.0    8.0  POLYGON ((281250.000 382000.000, 281450.000 38...
# 1     2.0     4.0   10.0  POLYGON ((281450.000 382000.000, 281650.000 38...
# 2     2.0     NaN   13.0  POLYGON ((281670.000 381800.000, 281850.000 38...
# 3     1.0     4.0    8.0  POLYGON ((281230.000 381800.000, 281250.000 38...
# 4     1.0     NaN    6.0  POLYGON ((280850.000 381800.000, 281230.000 38...
# ...   ...     ...    ...                                                ...
# 1624  NaN     4.0    7.0  MULTIPOLYGON (((281850.000 352300.000, 282250....
# 1625  NaN     4.0    7.0  MULTIPOLYGON (((281850.000 352300.000, 282250....
# 1626  NaN     4.0    7.0  MULTIPOLYGON (((281850.000 352300.000, 282250....
# 1627  NaN     4.0    6.0  MULTIPOLYGON (((281850.000 352300.000, 282250....
# 1628  NaN     4.0    6.0  MULTIPOLYGON (((281850.000 352300.000, 282250....
#
# [1629 rows x 4 columns]

# %%
shp.describe()
# Out:
#                 LU      Status        Slope
# count  1255.000000  816.000000  1625.000000
# mean      1.834263    3.004902     8.120000
# std       0.832708    1.143657     4.826778
# min       1.000000    1.000000     0.000000
# 25%       1.000000    3.000000     5.000000
# 50%       2.000000    3.000000     7.000000
# 75%       3.000000    4.000000    10.000000
# max       3.000000    4.000000    37.000000

# %%
print(shp['LU'].value_counts(dropna=False))
print(shp['Status'].value_counts(dropna=False))
slopes = shp['Slope'].value_counts()
# Out:
# 1.0    556
# NaN    374
# 2.0    351
# 3.0    348
# Name: LU, dtype: int64
# NaN    813
# 4.0    358
# 3.0    281
# 1.0    177
# Name: Status, dtype: int64

# %%
slopes.sort_index(inplace=True)

fig = plt.figure(figsize=(15, 8))
num_ticks = len(slopes)
plt.locator_params(axis="x", nbins=num_ticks)
# plt.plot(slopes)
plt.bar(slopes.index, slopes.values, alpha=0.5)
    
plt.xlabel("Slope")
plt.ylabel("Frequency")

plt.show()

# %%
slopes
# Out:
# 0.0       8
# 1.0      27
# 2.0      77
# 3.0      73
# 4.0     121
# 5.0     215
# 6.0     134
# 7.0     259
# 8.0     146
# 9.0     108
# 10.0     83
# 11.0     76
# 12.0     67
# 13.0     44
# 14.0     31
# 15.0     25
# 16.0     23
# 17.0     25
# 18.0     11
# 19.0     19
# 20.0      3
# 21.0      5
# 22.0     15
# 23.0      4
# 24.0      7
# 25.0      6
# 26.0      2
# 27.0      4
# 28.0      3
# 30.0      3
# 37.0      1
# Name: Slope, dtype: int64

# %%
shp.crs
# Out:
# <Projected CRS: EPSG:27700>
# Name: OSGB 1936 / British National Grid
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: UK - Britain and UKCS 49°45'N to 61°N, 9°W to 2°E
# - bounds: (-9.0, 49.75, 2.01, 61.01)
# Coordinate Operation:
# - name: British National Grid
# - method: Transverse Mercator
# Datum: OSGB 1936
# - Ellipsoid: Airy 1830
# - Prime Meridian: Greenwich

# %%
# fig, axs = plt.subplots(1, 3, figsize=(20, 8))
f, ax = plt.subplots(1, figsize=(8, 8))
ax = shp.plot(ax=ax, column='Slope', legend=True, legend_kwds={'label': "Slope"})
plt.title("BY SLOPE")
plt.show()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, figsize=(30, 10))
shp.plot(ax=ax1, column='LU', cmap='GnBu', legend=True, legend_kwds={'label': "LU"})
ax1.set_title('Conwy LU')
shp.plot(ax=ax2, column='Status', cmap='YlOrBr', legend=True, legend_kwds={'label': "Status"})
ax2.set_title('Conwy Status')
shp.plot(ax=ax3, column='Slope', cmap='YlGn', legend=True, legend_kwds={'label': "Slope"})
ax3.set_title('Conwy Slope')

plt.show()

# %%
fig, ax = plt.subplots(1, figsize=(10, 10))
shp.boundary.plot(ax=ax)

plt.show()

# %%
shx = gpd.read_file('Conwy.shx')

# %%
shx
# Out:
#        LU  Status  Slope                                           geometry
# 0     1.0     4.0    8.0  POLYGON ((281250.000 382000.000, 281450.000 38...
# 1     2.0     4.0   10.0  POLYGON ((281450.000 382000.000, 281650.000 38...
# 2     2.0     NaN   13.0  POLYGON ((281670.000 381800.000, 281850.000 38...
# 3     1.0     4.0    8.0  POLYGON ((281230.000 381800.000, 281250.000 38...
# 4     1.0     NaN    6.0  POLYGON ((280850.000 381800.000, 281230.000 38...
# ...   ...     ...    ...                                                ...
# 1624  NaN     4.0    7.0  MULTIPOLYGON (((281850.000 352300.000, 282250....
# 1625  NaN     4.0    7.0  MULTIPOLYGON (((281850.000 352300.000, 282250....
# 1626  NaN     4.0    7.0  MULTIPOLYGON (((281850.000 352300.000, 282250....
# 1627  NaN     4.0    6.0  MULTIPOLYGON (((281850.000 352300.000, 282250....
# 1628  NaN     4.0    6.0  MULTIPOLYGON (((281850.000 352300.000, 282250....
#
# [1629 rows x 4 columns]

# %%
f, ax = plt.subplots(1, figsize=(8, 8))
ax = shx.plot(ax=ax, column='Slope', legend=True, legend_kwds={'label': "Slope"})
plt.title("BY SLOPE")
plt.show()

# %%
dbf = gpd.read_file('Conwy.dbf')
dbf
# Out:
#        LU  Status  Slope                                           geometry
# 0     1.0     4.0    8.0  POLYGON ((281250.000 382000.000, 281450.000 38...
# 1     2.0     4.0   10.0  POLYGON ((281450.000 382000.000, 281650.000 38...
# 2     2.0     NaN   13.0  POLYGON ((281670.000 381800.000, 281850.000 38...
# 3     1.0     4.0    8.0  POLYGON ((281230.000 381800.000, 281250.000 38...
# 4     1.0     NaN    6.0  POLYGON ((280850.000 381800.000, 281230.000 38...
# ...   ...     ...    ...                                                ...
# 1624  NaN     4.0    7.0  MULTIPOLYGON (((281850.000 352300.000, 282250....
# 1625  NaN     4.0    7.0  MULTIPOLYGON (((281850.000 352300.000, 282250....
# 1626  NaN     4.0    7.0  MULTIPOLYGON (((281850.000 352300.000, 282250....
# 1627  NaN     4.0    6.0  MULTIPOLYGON (((281850.000 352300.000, 282250....
# 1628  NaN     4.0    6.0  MULTIPOLYGON (((281850.000 352300.000, 282250....
#
# [1629 rows x 4 columns]

# %%
f, ax = plt.subplots(1, figsize=(8, 8))
ax = dbf.plot(ax=ax, column='Slope', legend=True, legend_kwds={'label': "Slope"})
plt.title("BY SLOPE")
plt.show()

# %%
# pip install pyshp
import shapefile
import osr
from io import StringIO

# %%
dbf_new = open("Conwy.dbf", "rb")
shp_new = open("Conwy.shp", "rb")
shx_new = open("Conwy.shx", "rb")

# prj_new = open("Conwy.prj", "rb")
# prj_new = shapefile.Reader("Conwy.prj")
prj_new = StringIO("Conwy.prj")

# %%
r = shapefile.Reader(shp=shp_new, shx=shx_new, dbf=dbf_new)
r.numRecords
# Out:
# 1629

# %%
prj_tmp = 'PROJCS["OSGB_1936_British_National_Grid",GEOGCS["GCS_OSGB 1936",DATUM["D_OSGB_1936",SPHEROID["Airy_1830",6377563.396,299.3249646]],PRIMEM["Greenwich",0],UNIT["Degree",0.017453292519943295]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",49],PARAMETER["central_meridian",-2],PARAMETER["scale_factor",0.9996012717],PARAMETER["false_easting",400000],PARAMETER["false_northing",-100000],UNIT["Meter",1]]'

# %%
prj4 = osr.SpatialReference(prj_tmp).ExportToProj4()
prj4
# Out:
# '+proj=tmerc +lat_0=49 +lon_0=-2 +k=0.9996012717 +x_0=400000 +y_0=-100000 +ellps=airy +units=m +no_defs'

# %% [markdown]
# ### After a while I think only the <code>.shp</code> file is needed
